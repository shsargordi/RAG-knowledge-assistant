# %% [markdown]
# ### Evaluatiing our RAG

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.28711770538226206, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback='The generated answer correctly identifies **Maxine** as the 2023 IIOTY award winner, matching the core fact of the reference answer. However, it omits the surname (“Thompson”), which is a small but relevant detail.\n\n**Accuracy: 5** – The factual statement is correct.\n**Completeness: 4** – The answer could be more complete by including the full name, but it still conveys the essential information.\n**Relevance: 5** – The response directly answers the question with no extraneous details.', accuracy=5.0, completeness=4.0, relevance=5.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The generated answer correctly identifies **Maxine** as the 2023 IIOTY award winner, matching the core fact of the reference answer. However, it omits the surname (“Thompson”), which is a small but relevant detail.
#
# **Accuracy: 5** – The factual statement is correct.
# **Completeness: 4** – The answer could be more complete by including the full name, but it still conveys the essential information.
# **Relevance: 5** – The response directly answers the question with no extraneous details.
# 5.0
# 4.0
# 5.0
